# %% [markdown]
# <hr>
#
# <center>
#     Class: Machine Learning in Computational Biology <br>
#     Program: Data Science and Information Technologies <br>
#     Name: Aris <br>
#     Las name: Podotas <br>
#     ID: 7115152400040 <br>
#     Assignment: 1 <br>
# </center>
#
# <hr>

# %%
import matplotlib.pyplot as plt
import numpy as np
import os # I might not use this
import pandas as pd
from sklearn.linear_model import BayesianRidge, ElasticNet
from sklearn.metrics import root_mean_squared_error, mean_absolute_error, median_absolute_error, r2_score # spoilers
from sklearn.svm import SVR
import sys
sys.path.append('../src/')
import functions as utils

# %% [markdown]
# <hr>
#
# # Model development
#
# <hr>

# %%
root = '../data/'
dev = pd.read_csv(root + 'development_final_data.csv')
dev.head(10)
# Out:
#    Unnamed: 0  Project ID  Sex  Host age    BMI  Acholeplasma axanthum  \
# 0           0           5    0      53.0  19.01              -0.116074
# 1           1           3    1      21.0  23.50              -0.108980
# 2           2           3    0      52.0  25.80              -0.106369
# 3           3           5    1      40.0  23.49              -0.116074
# 4           4           5    1      30.0  22.60              -0.096208
# 5           5           5    0      21.0  26.25              -0.116074
# 6           6           3    0      52.0  25.80              -0.116074
# 7           7           3    0      52.0  25.80              -0.116074
# 8           8           5    0      42.0  24.75              -0.038767
# 9           9           5    0      67.0  28.70              -0.116074
#
#    Acidaminococcus fermentans  Acidaminococcus intestini  Actinomyces lingnae  \
# 0                   -0.151651                  -0.366867            -0.154353
# ...

# %%
val = pd.read_csv(root + 'evaluation_final_data.csv')
val.head(10)
del root

# %%
# Calling the models with all the fields because I'm curious to see if the "metadata" fields perform better

# Varible to hold model options
options = np.array([BayesianRidge, SVR, ElasticNet])
metrics = np.array([root_mean_squared_error, mean_absolute_error, median_absolute_error, r2_score]) # Look to the report or the readme for why this extra metric
train, preds = utils.isolator(dev)
validation, truth = utils.isolator(val)

# Defined in functions.py or the renamed utils
predictions = utils.regressions(options, train, preds, validation)
scores = utils.applyMetrics(metrics, options, truth, predictions)
utils.visualisePredictions(predictions, options, verbose = True)
utils.visualiseEvaluations(scores, options, metrics, verbose = True)
# Out:
# Function 'isolator' executed in 0.0027 seconds
# Function 'isolator' executed in 0.0011 seconds
# Function 'regressions' executed in 0.1134 seconds
# Function 'applyMetrics' executed in 0.0145 seconds
# [[25.72192296 25.82965562 24.5704497  25.7351903  25.55738605 25.48379784
#   22.23277817 28.54048058 26.35274565 25.86663071 23.36563427 23.65294957
#   25.36187805 22.20120515 27.35805961 23.69629128 23.68030616 26.19537288
#   26.24805295 24.80353778 23.90709639 23.7450534  26.98270175 25.19405501
#   25.32652134 25.31397995 24.38826944 25.20551188 21.95693862 25.54756297
#   22.46352044 24.1844329  21.60983164 25.58315046 25.38992461 23.99536467
#   25.61046962 25.53590983 26.68407913 22.87187018 26.64167877 28.13694303
#   25.37761013 22.63138526 24.99315307 25.02744511 21.86106396 18.34904011
#   25.41704138 22.10700694 25.11237767 23.32746254 24.27218339 19.28984128
#   24.15129297 26.42393119 25.50056589 25.42260041 25.53993833 26.39411781
# ...

# %%
bootstrap = utils.bootstrapVal(1000, dev, val, options, metrics, plot = True, verbose = False)
del bootstrap
bootstrap = utils.bootstrapDev(1000, dev, val, options, metrics, plot = True, verbose = False)
del bootstrap
bootstrap = utils.bootstrapBoth(1000, dev, val, options, metrics, plot = True, verbose = False)
del bootstrap
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:16<00:00, 61.51it/s]
# Function 'showConfidence' executed in 4.8839 seconds
# Function 'bootstrapVal' executed in 21.1869 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:00<00:00, 16.65it/s]
# Function 'showConfidence' executed in 5.3778 seconds
# Function 'bootstrapDev' executed in 65.4552 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:01<00:00, 16.15it/s]
# Function 'showConfidence' executed in 5.2108 seconds
# Function 'bootstrapBoth' executed in 67.1541 seconds

# %%
results = utils.applyKfold(train, preds, options, metrics, 50, 20)
del results # I just don't want the notebook to print automatically
# Out:
# 1000it [00:45, 22.13it/s]
# Function 'applyKfold' executed in 46.0104 seconds

# %%
utils.saveModels(utils.fitting(options, train, preds), f'../models/Baseline/', f'Baseline_with_metadata')
# Out:
# Function 'fitting' executed in 0.0427 seconds
# Function 'saveModels' executed in 0.0061 seconds

# %% [markdown]
# <hr>
#
# Remember that the above calls contain features such as ```Project ID```. The potential success of the median metric can be seen.
#
# Now we will do the same for the actual baseline models of the task at hand, that being the ```BMI``` being our $y$ and the species being the $x$'s.
#
# <hr>

# %%
# I'm going to split the development dataframe in data and metadata that I kept
devData, devMeta = utils.dataSplit(dev)
valData, valMeta = utils.dataSplit(val)
# Splitting data and validation to x's and y's
# Something that I dont realy use more from here i dont think because all function will calculate the split themselves
# The dataSplit function is used however
train, preds = utils.isolator(devData)
validation, truth = utils.isolator(valData)
predictions = utils.regressions(options, train, preds, validation)
scores = utils.applyMetrics(metrics, options, truth, predictions)
utils.visualisePredictions(predictions, options, verbose = False)
utils.visualiseEvaluations(scores, options, metrics, verbose = False)
# It won't matter that we cast over previous varibles since we don't ever consider the previous baseline anyway
scoresBaseline = scores # Used in the the other requirements
# Out:
# Function 'dataSplit' executed in 0.0010 seconds
# Function 'dataSplit' executed in 0.0000 seconds
# Function 'isolator' executed in 0.0010 seconds
# Function 'isolator' executed in 0.0010 seconds
# Function 'regressions' executed in 0.0616 seconds
# Function 'applyMetrics' executed in 0.0050 seconds
# Function 'visualisePredictions' executed in 0.2444 seconds
# Function 'visualiseEvaluations' executed in 1.1214 seconds

# %% [markdown]
# <hr>
#
# The two calls to the medels and evaluation above are for proof of concept, now we will run the actual baseline models with the multi evaluation bootstrap.
#
# <hr>

# %%
bootstrap = utils.bootstrapVal(1000, devData, valData, options, metrics, plot = True, verbose = False)
del bootstrap
bootstrap = utils.bootstrapDev(1000, devData, valData, options, metrics, plot = True, verbose = False)
del bootstrap
bootstrapBaseline = utils.bootstrapBoth(1000, devData, valData, options, metrics, plot = True, verbose = False) # Going to use this in the next requirements
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:14<00:00, 66.71it/s]
# Function 'showConfidence' executed in 4.9051 seconds
# Function 'bootstrapVal' executed in 19.9385 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:55<00:00, 18.06it/s]
# Function 'showConfidence' executed in 5.3390 seconds
# Function 'bootstrapDev' executed in 60.7315 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:59<00:00, 16.91it/s]
# Function 'showConfidence' executed in 5.0508 seconds
# Function 'bootstrapBoth' executed in 64.1790 seconds

# %%
# k fold cross validation
kfoldBaseline = utils.applyKfold(train, preds, options, metrics, 50, 20)
# Out:
# 1000it [00:41, 23.84it/s]
# Function 'applyKfold' executed in 43.2416 seconds

# %%
utils.saveModels(utils.fitting(options, train, preds), f'../models/Baseline/', f'Baseline_just_species')
# Out:
# Function 'fitting' executed in 0.0283 seconds
# Function 'saveModels' executed in 0.0177 seconds

# %% [markdown]
# <hr>
#
# # Model evaluation
#
# ## Bootstrap
#
# While atttempting to implement a bootstrap pipeline for the models three main ideas were encountered. Bootsraping just the ```Training set```, just the ```Validaton set``` and bootstraping both the ```Training``` and ```Validation set```. All three capture a different essence of evaluation.
#
# ### Just the validation set
#
# This serves as a form of validation for our one baseline model made with all the data so it's as if we create more validation sets out of our one full set by permuting it.
#
# ### Just the training set
#
# This is like the k-fold cross validation if the one split wanst for the validation but we used the same validation set for each model, we essentially make more than one model and evaluate it on the same baseline evaluation set so we compare subsets of training data from the dev set.
#
# ### Both simultaniously
#
# This simulates closer to a k-fold cross validation as both the training set and the validation set change on each iteration.
#
# ## K-fold
#
# The k-fold cross validation is different to the bootstrap methods used before and the distributions of the metric results for each model reflect this. The distributions are wider than the ones in the bootstrap section. The negative r2 score is indicative of more improvements to be made to the models.
#
# ## Saving naming scheme
#
# We will isolate different sections of the exercise into seperate folders named after the requirement we are on at each point (i.e. Baseline FeatureSelection and Tuned). The general naming scheme inside each folder will be "{regression method}\_{requirement specifier}\_{data involved}"
#
# ## Final baseline thoughts and comments
#
# Having a negative r2 score is indicative we have more improvements to make. The same metrics between different modelsdo not differ greatly in distribution. The boxplots of each individual run for each model during the bootstrap shows that the different models have a different tendencies to be spread around the mean value with the bayesian ridge being the most spread distribution on average and the elastic net hte least. The SVR has a tendency to lean to lower values than higher values when farther from the mean values are considered, resembling a gamma dstribution more than a standard Gaussian.
#
# # Feature selection models
#
# In order to contiue we should choose one of the two of these baselines to use since we cannot continue to have the whole analysis bisected by the two baseline models. This has to with the original reason we did two baseline models in the first place, we know a-priori that we search for a relation between the ```BMI``` and the ```species``` of organisms. When re-factored in to this frame we must chose the second baseline model (```Baseline_just_species```).
#
# <hr>

# %%
# Remember that we have kept the variables in the envoiroment from the previous cells up till now
# pca
utils.searchPca(train)
holder = utils.fitPca(train, 95)
trainPca = utils.applyPca(train, holder)
valPca = utils.applyPca(validation, holder) # Notice that we don't have the predictions in here
del holder # We won't need this anymore so we clean memory
# Out:
# Function 'searchPca' executed in 0.1853 seconds
# Function 'fitPca' executed in 0.0183 seconds
# Function 'applyPca' executed in 0.0000 seconds
# Function 'applyPca' executed in 0.0135 seconds

# %%
# Removing correlated features
#utils.correlation(train)
#trainPearson = utils.pearsonPrune(train, 0.75)
# Didnt get this to work yet

# %% [markdown]
# <hr>
#
# We have normalized the blue curve to the max of the red one so that both can have the same level of detail, otherwise the blue vurve would be up to $1$ on the plot and the red one would be invisible. Since the blue curve expresses the % of the total variance explained by all the components up to the one of the x axis you can see it as going from $0$ to $1$ on the plot where $1$ is normalized to $0.06$. These two seem to share a relationship (as could have been summized from the way they are calculated) of a function and it's derivative (like $ln(x)$ and $\frac{1}{x}$).
#
# There is a good reason to run the principal component analysis before the pearson correlation pruning since the values of the Pearson matrix will evaluate to the same values for each set of features but the principaled component with the most variance will be of the new pruned set and effectivly different.
#
# <hr>

# %%
predictions = utils.regressions(options, trainPca, preds, valPca)
scores = utils.applyMetrics(metrics, options, truth, predictions)
utils.visualisePredictions(predictions, options, verbose = False)
utils.visualiseEvaluations(scores, options, metrics, verbose = False)
# Out:
# Function 'regressions' executed in 0.0501 seconds
# Function 'applyMetrics' executed in 0.0050 seconds
# Function 'visualisePredictions' executed in 0.2179 seconds
# Function 'visualiseEvaluations' executed in 0.6096 seconds

# %% [markdown]
# <hr>
#
# It would seem that these models tend to predict lower values of their respective distributions as the SVR did before but now each models has exibited this behaviour. Essentially fitting a gamma distribution that has sharp falloff for higher values but a mean close to the higher end none the less.
#
# A commentairy on the metrics is due but we would like a little more of a direct comparison so the following cells is for measuring the difference the feature selection made.
#
# <hr>

# %%
# Metric comparisons with previous models
comparison = utils.compareMetrics(scoresBaseline, scores)
utils.visualiseEvaluations(comparison, options, metrics, verbose = False)
del comparison
# Out:
# Function 'compareMetrics' executed in 0.0000 seconds
# Function 'visualiseEvaluations' executed in 0.6805 seconds

# %% [markdown]
# <hr>
#
# Note that the above plots are of the difference in metric evaluation between the baseline model and the current model. Negative values mean that the current feature selected has a higher score by $|x|$ for that metric and method.
#
# Mostly negative values exist so our evaluation metrics are worse for the most part, we will need to confirm this at the k-fold validation.
#
# <hr>

# %%
# I need to generate the dataframe with the predictions again for each of these
devPca = trainPca.copy()
wholeValPca = valPca.copy()
devPca.insert(0, 'BMI', preds)
wholeValPca.insert(0, 'BMI', truth)

# %%
bootstrap = utils.bootstrapVal(1000, devPca, wholeValPca, options, metrics, plot = True, verbose = False)
del bootstrap
bootstrap = utils.bootstrapDev(1000, devPca, wholeValPca, options, metrics, plot = True, verbose = False)
del bootstrap
bootstrapFeatureSelection = utils.bootstrapBoth(1000, devPca, wholeValPca, options, metrics, plot = True, verbose = False)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:29<00:00, 33.64it/s]
# Function 'showConfidence' executed in 5.0343 seconds
# Function 'bootstrapVal' executed in 34.8004 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:49<00:00, 20.01it/s]
# Function 'showConfidence' executed in 5.2613 seconds
# Function 'bootstrapDev' executed in 55.2473 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:50<00:00, 19.90it/s]
# Function 'showConfidence' executed in 6.1614 seconds
# Function 'bootstrapBoth' executed in 56.4256 seconds

# %%
holder = utils.compareBootstrap(bootstrapBaseline[1], bootstrapFeatureSelection[1])
utils.visualiseComparedBootstrap(holder, options, metrics, verbose = False)
del holder
del bootstrapFeatureSelection
# Out:
# Function 'compareBootstrap' executed in 0.0000 seconds
# Function 'visualiseComparedBootstrap' executed in 1.6044 seconds

# %%
kfoldFeatureSelect = utils.applyKfold(trainPca, preds, options, metrics, 50, 20)
# Out:
# 1000it [00:37, 26.47it/s]
# Function 'applyKfold' executed in 38.5330 seconds

# %%
holder = utils.compareKfold(kfoldBaseline, kfoldFeatureSelect)
utils.visualiseComparedKfold(holder, options, metrics)
del holder
del kfoldFeatureSelect
# Out:
# Function 'compareKfold' executed in 0.0073 seconds
# Function 'visualiseComparedKfold' executed in 0.9317 seconds

# %%
utils.saveModels(utils.fitting(options, train, preds), f'../models/FeatureSelected/', f'FeatureSelected')
# Out:
# Function 'fitting' executed in 0.0363 seconds
# Function 'saveModels' executed in 0.0050 seconds

# %% [markdown]
# <hr>
#
# The comparison functions are ones that shift one distribution on the x axis by a factor of the other distribution. Notice that most of our metrics end up as unit variance zero mean distributions with slight disturbances (the mean is not exactly $0$). This is to say that the feature selection did not affect the final outputs much.
#
# ## Disclaimer
#
# We are going to use all $3$ optimized models below despite only needing to save one of the in the end for our best choice. This will be done because optuna (though it can decide) doesnt choose the best regressor to use in our functions since it doesnt minimize all the metrics at the same time for all the modesl. We are curious to see the results of each regressor in any case.
#
# We will choose to minimize the RMSE since it is the metric with the highers values till now.
#
# <hr>

# %%
# Fine tuning using optuna, look to the function definitions for more on that
ridgeTuned = utils.optimizeRidge(root_mean_squared_error, trainPca, preds, valPca, truth)
svrTuned = utils.optimizeSVR(root_mean_squared_error, trainPca, preds, valPca, truth)
netTuned = utils.optimizeNet(root_mean_squared_error, trainPca, preds, valPca, truth)

arguments = [ridgeTuned, svrTuned, netTuned]

predictions = utils.regressions(options, trainPca, preds, valPca, arguments = arguments)
scores = utils.applyMetrics(metrics, options, truth, predictions)
utils.visualisePredictions(predictions, options, verbose = False)
utils.visualiseEvaluations(scores, options, metrics, verbose = False)
# Out:
# [I 2025-03-24 21:16:50,397] A new study created in memory with name: no-name-8282d420-2c2a-40af-9265-2f0de3546814
# [I 2025-03-24 21:16:50,409] Trial 0 finished with value: 4.24555672421312 and parameters: {'alpha_1': 6.786108771127094e-05, 'alpha_2': 2.3850929391223673e-05, 'lambda_1': 5.170495709431318e-07, 'lambda_2': 8.000190182609662e-05}. Best is trial 0 with value: 4.24555672421312.
# [I 2025-03-24 21:16:50,421] Trial 1 finished with value: 4.245550313365068 and parameters: {'alpha_1': 8.022962133227359e-05, 'alpha_2': 5.38489869191042e-05, 'lambda_1': 8.036801055400034e-05, 'lambda_2': 7.397923600300352e-05}. Best is trial 1 with value: 4.245550313365068.
# [I 2025-03-24 21:16:50,434] Trial 2 finished with value: 4.245565584638065 and parameters: {'alpha_1': 3.972838210031661e-05, 'alpha_2': 8.173512015542004e-05, 'lambda_1': 2.49669886893642e-05, 'lambda_2': 9.159227091252267e-05}. Best is trial 1 with value: 4.245550313365068.
# ...

# %% [markdown]
# <hr>
#
# No more negative predictions were made in the data.
#
# <hr>

# %%
bootstrap = utils.bootstrapVal(1000, devPca, wholeValPca, options, metrics, plot = True, verbose = False, arguments = arguments)
del bootstrap
bootstrap = utils.bootstrapDev(1000, devPca, wholeValPca, options, metrics, plot = True, verbose = False, arguments = arguments)
del bootstrap
bootstrapFinals = utils.bootstrapBoth(1000, devPca, wholeValPca, options, metrics, plot = True, verbose = False, arguments = arguments)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:13<00:00, 76.40it/s]
# Function 'showConfidence' executed in 5.2184 seconds
# Function 'bootstrapVal' executed in 18.3440 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:47<00:00, 21.20it/s]
# Function 'showConfidence' executed in 5.1374 seconds
# Function 'bootstrapDev' executed in 52.3185 seconds
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:48<00:00, 20.67it/s]
# Function 'showConfidence' executed in 5.2515 seconds
# Function 'bootstrapBoth' executed in 53.6389 seconds

# %%
holder = utils.compareBootstrap(bootstrapBaseline[1], bootstrapFinals[1])
utils.visualiseComparedBootstrap(holder, options, metrics, verbose = False)
del holder
del bootstrapFinals
# Out:
# Function 'compareBootstrap' executed in 0.0010 seconds
# Function 'visualiseComparedBootstrap' executed in 1.4636 seconds

# %% [markdown]
# <hr>
#
# It seems here, in the bootstrap that we get the negative BMI predictions again. This does not pose a problem seeing that the training sets from each bootstrap teration do not represent the final models.
#
# <hr>

# %%
kfoldFinals = utils.applyKfold(trainPca, preds, options, metrics, 50, 20, arguments = arguments)
# Out:
# 1000it [00:35, 28.52it/s]
# Function 'applyKfold' executed in 35.9017 seconds

# %%
holder = utils.compareKfold(kfoldBaseline, kfoldFinals)
utils.visualiseComparedKfold(holder, options, metrics)
del holder
del kfoldFinals
# Out:
# Function 'compareKfold' executed in 0.0067 seconds
# Function 'visualiseComparedKfold' executed in 0.9439 seconds

# %% [markdown]
# <hr>
#
# # Conclusions
#
# our models seems to have only improved very slightly for each different permutation we have done. The feature selection and the optimization of the hyper parameters did not significantly change the metrics or the distributions most of the time. The most significant change is of the SVR and the elastic net for the final models that have had tighter distributions till now in general but the tightest distributions for the final models. This would not be an issue in and of itself however the distributions does not cover all the values of the BMI range we have at our disposal (i.e. $\geq 30$). It would seem that from the results of this small study that we cannot properly solve this regression problem using these 3 methods to a degree of satisfacton. Considering neural networks is a last resort for problems like these since they are the most computationally demanding, here it would not be out of the question to try a neural network.
#
# <hr>

# %%
utils.saveModels(utils.fitting(options, train, preds, arguments = arguments), f'../models/final_models/', f'final_model_feature_selected')
# Out:
# Function 'fitting' executed in 0.0341 seconds
# Function 'saveModels' executed in 0.0050 seconds

# %% [markdown]
# <hr>
#
# # Choosing a final model
#
# We will be using the bayesian ridge model since it has the distribution that seems to cover most of the values of the BMI actually present in the data. It cant predict high and low values of our outputs while both the support vector and the elastic net seem to have a very tight distribution around the mean of the distributions. The bayesian ridge did predict some of the validation set as having negative BMI values in the bootstrap iterations but we can move past that since that iteration of the bootstrap loop does not represent the model fully, once trained on the whole data it is a more representative model. The metrics of each model are almost identical.
#
# <hr>

# %%
# Implementing a pipeline for the last model
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import joblib

totalData = pd.concat([devPca, wholeValPca])
x, y = utils.isolator(totalData)

winner = Pipeline([('scaler', StandardScaler()), ('feature_selector', PCA(n_components=95)), ('model', BayesianRidge(**ridgeTuned))])
winner.fit(x, y)
joblib.dump(winner, f"../models/final_models/winner.pkl")
print(winner.predict(valPca))
# Out:
# Function 'isolator' executed in 0.0010 seconds
# [23.60158846 25.25766033 22.96164511 25.27883864 25.25766033 25.01289325
#  24.69048135 27.02017008 25.40136121 23.5884009  24.66480679 26.05865024
#  24.67075225 24.57490512 25.26125422 24.71528655 24.58450515 24.85561548
#  25.83744574 25.38933227 26.53868734 24.1505777  25.18159189 24.67883765
#  25.32577741 25.25766033 23.97114383 24.83474894 21.07483198 25.45734644
#  25.23858947 25.21846401 23.8330532  25.7655056  25.04821793 25.09727628
#  25.87923975 26.4790631  25.65922117 25.14503296 24.96085391 26.06706115
#  24.61040635 23.98459139 25.20514674 25.24873454 25.55032151 23.04161071
#  25.25766033 22.80816924 24.59680126 23.4348059  25.16033017 24.45086976
#  25.22072763 24.59638137 24.85107558 24.69314821 25.26642575 24.60810406
#  24.64880426 25.48928271 23.64317997 24.16772357 24.76004652 25.30381169
#  23.96270753 24.83094243 25.25766033 23.65089046 27.48970758 27.33135877
# ...
